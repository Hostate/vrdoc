# %%
import pandas as pd
import random
num = 0
def naa():
    ret = []
    ret = random.sample(range(1,10), 5)
    list0 = []
    for i in ret:
        list0.append(i)
        list0.append(i)
    return list0
print(naa())
# Out:
# [1, 1, 4, 4, 3, 3, 5, 5, 7, 7]

# %%
import pandas as pd
import random
count = 1
def naa():
    ret = []
    ret = random.sample(range(1,10), 5)
    list0 = []
    for i in ret:
        list0.append(i)
        list0.append(i)
    return list0
def addhuan():
    ret = []
    while(1):
        a = random.randint(1,9)
        b = random.randint(1,9)
        if (a != b):
            break
    ret.append(a)
    ret.append(b)
    return ret
def naaa():
    ret = []
    ret = random.sample(range(1,10), 4)
    list0 = []
    for i in ret:
        list0.append(i)
        list0.append(i)
        list0.append(i)
    return list0
def nabb():
    ret = []
    for i in range(8):
        while(1):
            a = random.randint(1,9)
            b = random.randint(1,9)
            if (a != b):
                break
        ret.append(a)
        ret.append(b)
        ret.append(b)
    return ret
def wh():
    ret = []
    for i in range(4):
        x = random.randint(1,2)

        if (x == 1):#hang
            base = random.randint(1,3) *3 - 2
            ret.append(base)
            ret.append(base+1)
            ret.append(base+2)
        else:#lie
            base = random.randint(1,3)
            ret.append(base)
            ret.append(base+3)
            ret.append(base+6)
    return ret
def ncross():
    ret = []
    cross0 = [1, 5, 9]
    cross1 = [9, 5, 1]
    cross2 = [7, 5, 3]
    cross3 = [3, 5, 7]
    crosses = [cross0, cross1, cross2, cross3]
    for i in range(4):
        x = random.randint(1, 4)
        for j in crosses[x- 1]:
            ret.append(j)
    return ret
def abc3():
    ret = []
    for i in range(3):
        flag = 0
        while(flag == 0):
            a = random.randint(1, 9)
            b = random.randint(1, 9)
            c = random.randint(1, 9)
            if (a != b and a != c and b != c):
                flag = 1
                for x in range(3):
                    ret.append(a)
                    ret.append(b)
                    ret.append(c)
    return ret
list0 = []
for i in range(1, 10):
    list0.append(['pic/' + str(i) +'.png', "['{}']".format('num_' + str(i))])
dict0 = {}
for i in range(len(list0)):
    dict0[i+1] = list0[i]
num = []
for i in naa():
    num.append([i, 'aa'])
for i in addhuan():
    num.append([i, 'huan'])
for i in naaa():
    num.append([i, 'aaa'])
for i in addhuan():
    num.append([i, 'huan'])
for i in nabb():
    num.append([i, 'abb'])
for i in addhuan():
    num.append([i, 'huan'])
for i in wh():
    num.append([i, 'wh'])
for i in ncross():
    num.append([i, 'cross'])
for i in addhuan():
    num.append([i, 'huan'])
for i in abc3():
    num.append([i, 'abc3'])

ready = []
for i in range(len(num)):
    tem = dict0[num[i][0]][:]
    tem.append(num[i][1])
    if tem[2] != 'huan':
        tem.append(count)
        count+=1
    else:
        tem.append(-1)
    ready.append(tem)
data = pd.DataFrame(ready, columns = ['pic', 'ans', 'cla', 'no'])
data.to_csv('formal_click.csv', index = False)
# Out:
# ['pic/5.png', "['num_5']", 'aa', 1]
# ['pic/5.png', "['num_5']", 'aa', 2]
# ['pic/8.png', "['num_8']", 'aa', 3]
# ['pic/8.png', "['num_8']", 'aa', 4]
# ['pic/7.png', "['num_7']", 'aa', 5]
# ['pic/7.png', "['num_7']", 'aa', 6]
# ['pic/4.png', "['num_4']", 'aa', 7]
# ['pic/4.png', "['num_4']", 'aa', 8]
# ['pic/1.png', "['num_1']", 'aa', 9]
# ['pic/1.png', "['num_1']", 'aa', 10]
# ['pic/6.png', "['num_6']", 'huan', -1]
# ['pic/8.png', "['num_8']", 'huan', -1]
# ['pic/4.png', "['num_4']", 'aaa', 11]
# ['pic/4.png', "['num_4']", 'aaa', 12]
# ['pic/4.png', "['num_4']", 'aaa', 13]
# ['pic/3.png', "['num_3']", 'aaa', 14]
# ['pic/3.png', "['num_3']", 'aaa', 15]
# ['pic/3.png', "['num_3']", 'aaa', 16]
# ['pic/7.png', "['num_7']", 'aaa', 17]
# ['pic/7.png', "['num_7']", 'aaa', 18]
# ['pic/7.png', "['num_7']", 'aaa', 19]
# ['pic/8.png', "['num_8']", 'aaa', 20]
# ['pic/8.png', "['num_8']", 'aaa', 21]
# ['pic/8.png', "['num_8']", 'aaa', 22]
# ['pic/9.png', "['num_9']", 'huan', -1]
# ['pic/3.png', "['num_3']", 'huan', -1]
# ['pic/1.png', "['num_1']", 'abb', 23]
# ['pic/5.png', "['num_5']", 'abb', 24]
# ['pic/5.png', "['num_5']", 'abb', 25]
# ['pic/5.png', "['num_5']", 'abb', 26]
# ['pic/1.png', "['num_1']", 'abb', 27]
# ['pic/1.png', "['num_1']", 'abb', 28]
# ['pic/3.png', "['num_3']", 'abb', 29]
# ['pic/5.png', "['num_5']", 'abb', 30]
# ['pic/5.png', "['num_5']", 'abb', 31]
# ['pic/9.png', "['num_9']", 'abb', 32]
# ['pic/2.png', "['num_2']", 'abb', 33]
# ['pic/2.png', "['num_2']", 'abb', 34]
# ['pic/4.png', "['num_4']", 'abb', 35]
# ['pic/3.png', "['num_3']", 'abb', 36]
# ['pic/3.png', "['num_3']", 'abb', 37]
# ['pic/7.png', "['num_7']", 'abb', 38]
# ['pic/6.png', "['num_6']", 'abb', 39]
# ['pic/6.png', "['num_6']", 'abb', 40]
# ['pic/1.png', "['num_1']", 'abb', 41]
# ['pic/7.png', "['num_7']", 'abb', 42]
# ['pic/7.png', "['num_7']", 'abb', 43]
# ['pic/7.png', "['num_7']", 'abb', 44]
# ['pic/4.png', "['num_4']", 'abb', 45]
# ['pic/4.png', "['num_4']", 'abb', 46]
# ['pic/6.png', "['num_6']", 'huan', -1]
# ['pic/4.png', "['num_4']", 'huan', -1]
# ['pic/3.png', "['num_3']", 'wh', 47]
# ['pic/6.png', "['num_6']", 'wh', 48]
# ['pic/9.png', "['num_9']", 'wh', 49]
# ['pic/7.png', "['num_7']", 'wh', 50]
# ['pic/8.png', "['num_8']", 'wh', 51]
# ['pic/9.png', "['num_9']", 'wh', 52]
# ['pic/4.png', "['num_4']", 'wh', 53]
# ['pic/5.png', "['num_5']", 'wh', 54]
# ['pic/6.png', "['num_6']", 'wh', 55]
# ['pic/2.png', "['num_2']", 'wh', 56]
# ['pic/5.png', "['num_5']", 'wh', 57]
# ['pic/8.png', "['num_8']", 'wh', 58]
# ['pic/9.png', "['num_9']", 'cross', 59]
# ['pic/5.png', "['num_5']", 'cross', 60]
# ['pic/1.png', "['num_1']", 'cross', 61]
# ['pic/9.png', "['num_9']", 'cross', 62]
# ['pic/5.png', "['num_5']", 'cross', 63]
# ['pic/1.png', "['num_1']", 'cross', 64]
# ['pic/1.png', "['num_1']", 'cross', 65]
# ['pic/5.png', "['num_5']", 'cross', 66]
# ['pic/9.png', "['num_9']", 'cross', 67]
# ['pic/1.png', "['num_1']", 'cross', 68]
# ['pic/5.png', "['num_5']", 'cross', 69]
# ['pic/9.png', "['num_9']", 'cross', 70]
# ['pic/3.png', "['num_3']", 'huan', -1]
# ['pic/5.png', "['num_5']", 'huan', -1]
# ['pic/5.png', "['num_5']", 'abc3', 71]
# ['pic/9.png', "['num_9']", 'abc3', 72]
# ['pic/4.png', "['num_4']", 'abc3', 73]
# ['pic/5.png', "['num_5']", 'abc3', 74]
# ['pic/9.png', "['num_9']", 'abc3', 75]
# ['pic/4.png', "['num_4']", 'abc3', 76]
# ['pic/5.png', "['num_5']", 'abc3', 77]
# ['pic/9.png', "['num_9']", 'abc3', 78]
# ['pic/4.png', "['num_4']", 'abc3', 79]
# ['pic/7.png', "['num_7']", 'abc3', 80]
# ['pic/1.png', "['num_1']", 'abc3', 81]
# ['pic/3.png', "['num_3']", 'abc3', 82]
# ['pic/7.png', "['num_7']", 'abc3', 83]
# ['pic/1.png', "['num_1']", 'abc3', 84]
# ['pic/3.png', "['num_3']", 'abc3', 85]
# ['pic/7.png', "['num_7']", 'abc3', 86]
# ['pic/1.png', "['num_1']", 'abc3', 87]
# ['pic/3.png', "['num_3']", 'abc3', 88]
# ['pic/7.png', "['num_7']", 'abc3', 89]
# ['pic/4.png', "['num_4']", 'abc3', 90]
# ['pic/6.png', "['num_6']", 'abc3', 91]
# ['pic/7.png', "['num_7']", 'abc3', 92]
# ['pic/4.png', "['num_4']", 'abc3', 93]
# ['pic/6.png', "['num_6']", 'abc3', 94]
# ['pic/7.png', "['num_7']", 'abc3', 95]
# ['pic/4.png', "['num_4']", 'abc3', 96]
# ['pic/6.png', "['num_6']", 'abc3', 97]
